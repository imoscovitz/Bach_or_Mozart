# %%
# For funsies, I implemented Cohen's IREP, which learns a set of rules in DNF with pruning
# It's designed for categorical features, so I also implemented a simple binning procedure.

# If I had more time (and hopefully I soon will) I'd have implemented Robert's suggestion of
# searching for the optimal bin. Instead, I increased the number of bins
# because as a dnf it would hopefully be able to capture some of that optimization 
# with a longer ruleset.

# Cool! It actually performed as well as the other two best, SVM and Random Forest!

# %%
import IREP
import pandas as pd

# %%
# Load the dataset
train = pd.read_pickle('train_merged.pkl')

# %%
# Hide cheating attributes during training
omit_mask = ['Collection','Song','Snippet']

# %%
# Bin finely
bin_fit_dict = IREP.fit_bins(train, n_bins=10, ignore_feats=['Mode'])
binned_train = IREP.bin_transform(train, bin_fit_dict)
binned_df = IREP.fit_bins(train)

# %%
# I implemented CustomCV with scikit format in mind, so I'll use a repeated hold-out 100 times,
# with a 1/5 split, which I think should theoretically give me at least as conservative a result as CV.

results = IREP.experiment(binned_train.drop(omit_mask,axis=1),n=100,ttsplit=.2, display=True, sleep=False)
# Out:
# test 1
# Update: []
# Update: [('Mode', 1)]
# Update: [('Mode', 1), ('Poly_mean', '0.08-0.08')]
# Grown: [('Mode', 1), ('Poly_mean', '0.08-0.08'), ('Dissonance', '8.13-8.35')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_mean1', '23.23-26.7')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_var1', '23.24-24.78')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('Tempo', '89.0-99.0')]
# Grown: [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')]
# Pruned to: [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')]]
#
# Update: []
# Update: [('SContr_mean0', '23.38-24.23')]
# Grown: [('SContr_mean0', '23.38-24.23'), ('Poly_mean', '0.06-0.07')]
# Pruned to: [('SContr_mean0', '23.38-24.23')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')], [('SContr_mean0', '23.38-24.23')]]
#
# Update: []
# Update: [('SContr_mean0', '21.54-22.52')]
# Update: [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38')]
# Grown: [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38'), ('SContr_mean3', '26.41-26.91')]
# Pruned to: [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')], [('SContr_mean0', '23.38-24.23')], [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('SContr_var6', '10.62-11.37')]
# Pruned to: [('SContr_var0', '61.08-89.82'), ('SContr_var6', '10.62-11.37')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')], [('SContr_mean0', '23.38-24.23')], [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38')], [('SContr_var0', '61.08-89.82'), ('SContr_var6', '10.62-11.37')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Grown: [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')]
# Pruned to: [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')], [('SContr_mean0', '23.38-24.23')], [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38')], [('SContr_var0', '61.08-89.82'), ('SContr_var6', '10.62-11.37')], [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Update: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15'), ('Poly_mean', '0.08-0.08')]
# Pruned to: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')], [('SContr_mean0', '23.38-24.23')], [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38')], [('SContr_var0', '61.08-89.82'), ('SContr_var6', '10.62-11.37')], [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.09')]
# Update: [('Poly_mean', '0.08-0.09'), ('SContr_mean1', '23.23-26.7')]
# Grown: [('Poly_mean', '0.08-0.09'), ('SContr_mean1', '23.23-26.7'), ('SContr_mean3', '27.67-30.76')]
# Pruned to: [('Poly_mean', '0.08-0.09')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')], [('SContr_mean0', '23.38-24.23')], [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38')], [('SContr_var0', '61.08-89.82'), ('SContr_var6', '10.62-11.37')], [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('Poly_mean', '0.08-0.09')]]
#
# Update: []
# Update: [('SContr_mean3', '21.12-24.09')]
# Grown: [('SContr_mean3', '21.12-24.09'), ('SContr_var5', '9.26-15.4')]
# Pruned to: [('SContr_mean3', '21.12-24.09'), ('SContr_var5', '9.26-15.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_var6', '35.52-111.01')], [('SContr_mean0', '23.38-24.23')], [('SContr_mean0', '21.54-22.52'), ('Tonal_Clarity', '0.34-0.38')], [('SContr_var0', '61.08-89.82'), ('SContr_var6', '10.62-11.37')], [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('Poly_mean', '0.08-0.09')], [('SContr_mean3', '21.12-24.09'), ('SContr_var5', '9.26-15.4')]]
#
# Update: []
# Update: [('SContr_mean0', '21.54-22.52')]
# Grown: [('SContr_mean0', '21.54-22.52'), ('SContr_var6', '8.67-9.4')]
# Pruned to: [('SContr_mean0', '21.54-22.52'), ('SContr_var6', '8.67-9.4')]
# {'Precision': 0.8774193548387097, 'Recall': 1.1239669421487604}
# 0.8774193548387097 1.1239669421487604
# test 2
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var4', '11.93-12.86')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Grown: [('SContr_mean0', '25.51-28.21')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_var2', '32.97-56.39')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_var2', '19.0-21.38')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('Tempo', '99.0-112.0')]
# Pruned to: [('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('Tempo', '89.0-99.0')]
# Update: [('Tempo', '89.0-99.0'), ('Poly_mean', '0.08-0.08')]
# Grown: [('Tempo', '89.0-99.0'), ('Poly_mean', '0.08-0.08'), ('SContr_mean0', '23.38-24.23')]
# Pruned to: [('Tempo', '89.0-99.0'), ('Poly_mean', '0.08-0.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '61.08-89.82')], [('Tempo', '89.0-99.0'), ('Poly_mean', '0.08-0.08')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Update: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Grown: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08'), ('SContr_mean6', '36.88-45.02')]
# Pruned to: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '61.08-89.82')], [('Tempo', '89.0-99.0'), ('Poly_mean', '0.08-0.08')], [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]]
#
# Update: []
# Update: [('SContr_var1', '23.24-24.78')]
# Grown: [('SContr_var1', '23.24-24.78'), ('SContr_var0', '52.85-56.48')]
# Pruned to: [('SContr_var1', '23.24-24.78'), ('SContr_var0', '52.85-56.48')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '61.08-89.82')], [('Tempo', '89.0-99.0'), ('Poly_mean', '0.08-0.08')], [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')], [('SContr_var1', '23.24-24.78'), ('SContr_var0', '52.85-56.48')]]
#
# Update: []
# Update: [('SContr_mean4', '21.36-24.68')]
# Update: [('SContr_mean4', '21.36-24.68'), ('SContr_var0', '46.97-49.96')]
# Grown: [('SContr_mean4', '21.36-24.68'), ('SContr_var0', '46.97-49.96'), ('SCentr_Range', '2203.0-3255.0')]
# Pruned to: [('SContr_mean4', '21.36-24.68'), ('SContr_var0', '46.97-49.96'), ('SCentr_Range', '2203.0-3255.0')]
# {'Precision': 0.8636363636363636, 'Recall': 1.08130081300813}
# 0.8636363636363636 1.08130081300813
# test 3
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_mean0', '24.23-25.51')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('Poly_mean', '0.07-0.07')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var6', '35.52-111.01')]
# Update: [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')]
# Grown: [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45'), ('SCentr_Range', '3255.0-10320.0')]
# Pruned to: [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.08')]
# Update: [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '24.23-25.51')]
# Grown: [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '24.23-25.51'), ('SContr_var5', '6.61-6.95')]
# Pruned to: [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('Tempo', '99.0-112.0')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean1', '23.23-26.7')]
# Update: [('SContr_mean1', '23.23-26.7'), ('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_mean1', '23.23-26.7'), ('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')]
# Pruned to: [('SContr_mean1', '23.23-26.7'), ('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean1', '23.23-26.7'), ('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Pruned to: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean1', '23.23-26.7'), ('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]]
#
# Update: []
# Update: [('SContr_var2', '21.38-22.46')]
# Grown: [('SContr_var2', '21.38-22.46'), ('SCentr_Range', '1517.0-2203.0')]
# Pruned to: [('SContr_var2', '21.38-22.46'), ('SCentr_Range', '1517.0-2203.0')]
# {'Precision': 0.8849557522123894, 'Recall': 0.9433962264150944}
# 0.8849557522123894 0.9433962264150944
# test 4
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var5', '6.23-6.61')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('Tempo', '129.0-143.0')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_var6', '35.52-111.01')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_var3', '26.74-55.45')]
# Grown: [('SContr_var3', '26.74-55.45'), ('SContr_var0', '61.08-89.82')]
# Pruned to: [('SContr_var3', '26.74-55.45'), ('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_var3', '26.74-55.45'), ('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('Tempo', '129.0-143.0')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_var3', '26.74-55.45'), ('SContr_var0', '61.08-89.82')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_mean0', '21.54-22.52')]
# Grown: [('SContr_mean0', '21.54-22.52'), ('Tempo', '89.0-99.0')]
# Pruned to: [('SContr_mean0', '21.54-22.52')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_var3', '26.74-55.45'), ('SContr_var0', '61.08-89.82')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '21.54-22.52')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('SCentr_Range', '846.0-887.0')]
# Pruned to: [('SContr_mean0', '22.52-23.38'), ('SCentr_Range', '846.0-887.0')]
# {'Precision': 0.8321167883211679, 'Recall': 1.027027027027027}
# 0.8321167883211679 1.027027027027027
# test 5
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_mean0', '24.23-25.51')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_var2', '24.45-25.91')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var6', '35.52-111.01')]
# Grown: [('SContr_var6', '35.52-111.01'), ('SContr_var2', '32.97-56.39')]
# Pruned to: [('SContr_var6', '35.52-111.01'), ('SContr_var2', '32.97-56.39')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var6', '35.52-111.01'), ('SContr_var2', '32.97-56.39')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.09')]
# Grown: [('Poly_mean', '0.08-0.09'), ('SContr_mean1', '23.23-26.7')]
# Pruned to: [('Poly_mean', '0.08-0.09'), ('SContr_mean1', '23.23-26.7')]
# {'Precision': 0.855072463768116, 'Recall': 0.5363636363636364}
# 0.855072463768116 0.5363636363636364
# test 6
# Update: []
# Update: [('Mode', 1)]
# Update: [('Mode', 1), ('Poly_mean', '0.08-0.08')]
# Grown: [('Mode', 1), ('Poly_mean', '0.08-0.08'), ('SContr_var4', '11.93-12.86')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('Tempo', '129.0-143.0')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean2', '25.49-25.88')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('Interval_2', '4.31-4.42')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var3', '26.74-55.45')]
# Update: [('SContr_var3', '26.74-55.45'), ('SCentr_Range', '2203.0-3255.0')]
# Grown: [('SContr_var3', '26.74-55.45'), ('SCentr_Range', '2203.0-3255.0'), ('SContr_mean1', '19.18-19.91')]
# Pruned to: [('SContr_var3', '26.74-55.45')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var3', '26.74-55.45')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Grown: [('SContr_var5', '9.26-15.4'), ('SContr_mean1', '20.31-20.78')]
# Pruned to: [('SContr_var5', '9.26-15.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var3', '26.74-55.45')], [('SContr_var5', '9.26-15.4')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Pruned to: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var3', '26.74-55.45')], [('SContr_var5', '9.26-15.4')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]]
#
# Update: []
# Update: [('Tempo', '89.0-99.0')]
# Grown: [('Tempo', '89.0-99.0'), ('SContr_var0', '49.96-52.85')]
# Pruned to: [('Tempo', '89.0-99.0'), ('SContr_var0', '49.96-52.85')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var3', '26.74-55.45')], [('SContr_var5', '9.26-15.4')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('Tempo', '89.0-99.0'), ('SContr_var0', '49.96-52.85')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.09')]
# Grown: [('Poly_mean', '0.08-0.09'), ('SContr_mean6', '33.23-34.23')]
# Pruned to: [('Poly_mean', '0.08-0.09'), ('SContr_mean6', '33.23-34.23')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var3', '26.74-55.45')], [('SContr_var5', '9.26-15.4')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('Tempo', '89.0-99.0'), ('SContr_var0', '49.96-52.85')], [('Poly_mean', '0.08-0.09'), ('SContr_mean6', '33.23-34.23')]]
#
# Update: []
# Update: [('SContr_mean5', '25.95-34.8')]
# Update: [('SContr_mean5', '25.95-34.8'), ('SContr_mean3', '27.67-30.76')]
# Grown: [('SContr_mean5', '25.95-34.8'), ('SContr_mean3', '27.67-30.76'), ('SContr_mean4', '27.8-34.22')]
# Pruned to: [('SContr_mean5', '25.95-34.8'), ('SContr_mean3', '27.67-30.76'), ('SContr_mean4', '27.8-34.22')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_var3', '26.74-55.45')], [('SContr_var5', '9.26-15.4')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('Tempo', '89.0-99.0'), ('SContr_var0', '49.96-52.85')], [('Poly_mean', '0.08-0.09'), ('SContr_mean6', '33.23-34.23')], [('SContr_mean5', '25.95-34.8'), ('SContr_mean3', '27.67-30.76'), ('SContr_mean4', '27.8-34.22')]]
#
# Update: []
# Update: [('SContr_mean0', '21.54-22.52')]
# Grown: [('SContr_mean0', '21.54-22.52'), ('Interval_2', '3.84-3.97')]
# Pruned to: [('SContr_mean0', '21.54-22.52'), ('Interval_2', '3.84-3.97')]
# {'Precision': 0.8292682926829268, 'Recall': 1.2477064220183487}
# 0.8292682926829268 1.2477064220183487
# test 7
# Update: []
# Update: [('Mode', 1)]
# Update: [('Mode', 1), ('Poly_mean', '0.08-0.08')]
# Grown: [('Mode', 1), ('Poly_mean', '0.08-0.08'), ('SContr_var4', '11.93-12.86')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Grown: [('SContr_mean0', '25.51-28.21')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_var1', '23.24-24.78')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean0', '23.38-24.23')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean0', '21.54-22.52')]
# Grown: [('SContr_mean0', '21.54-22.52'), ('SContr_var3', '26.74-55.45')]
# Pruned to: [('SContr_mean0', '21.54-22.52')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '21.54-22.52')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('Tempo', '89.0-99.0')]
# Pruned to: [('SContr_mean0', '22.52-23.38')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '21.54-22.52')], [('SContr_mean0', '22.52-23.38')]]
#
# Update: []
# Update: [('SContr_mean0', '23.38-24.23')]
# Grown: [('SContr_mean0', '23.38-24.23'), ('SContr_var2', '28.06-32.97')]
# Pruned to: [('SContr_mean0', '23.38-24.23')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '21.54-22.52')], [('SContr_mean0', '22.52-23.38')], [('SContr_mean0', '23.38-24.23')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Grown: [('SContr_var5', '9.26-15.4'), ('SContr_var3', '17.42-18.14')]
# Pruned to: [('SContr_var5', '9.26-15.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '21.54-22.52')], [('SContr_mean0', '22.52-23.38')], [('SContr_mean0', '23.38-24.23')], [('SContr_var5', '9.26-15.4')]]
#
# Update: []
# Update: [('SContr_mean1', '23.23-26.7')]
# Grown: [('SContr_mean1', '23.23-26.7'), ('SCentr_Range', '846.0-887.0')]
# Pruned to: [('SContr_mean1', '23.23-26.7'), ('SCentr_Range', '846.0-887.0')]
# {'Precision': 0.7743589743589744, 'Recall': 1.3603603603603605}
# 0.7743589743589744 1.3603603603603605
# test 8
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var5', '6.23-6.61')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('Tempo', '89.0-99.0')]
# Grown: [('Tempo', '89.0-99.0'), ('SContr_mean2', '24.13-24.63')]
# Pruned to: [('Tempo', '89.0-99.0')]
# Updated ruleset: [[('Mode', 1)], [('Tempo', '89.0-99.0')]]
#
# Update: []
# Grown: [('SContr_mean0', '25.51-28.21')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('Tempo', '89.0-99.0')], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('Tempo', '129.0-143.0')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('Tempo', '89.0-99.0')], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('SContr_mean6', '33.23-34.23')]
# Pruned to: [('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('Mode', 1)], [('Tempo', '89.0-99.0')], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('Consonance', '8.1-8.34')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('Tempo', '89.0-99.0')], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '52.85-56.48')]
# Grown: [('SContr_var0', '52.85-56.48'), ('SContr_var1', '23.24-24.78')]
# Pruned to: [('SContr_var0', '52.85-56.48'), ('SContr_var1', '23.24-24.78')]
# Updated ruleset: [[('Mode', 1)], [('Tempo', '89.0-99.0')], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '52.85-56.48'), ('SContr_var1', '23.24-24.78')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Update: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Grown: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08'), ('SCentr_Range', '3255.0-10320.0')]
# Pruned to: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Updated ruleset: [[('Mode', 1)], [('Tempo', '89.0-99.0')], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '52.85-56.48'), ('SContr_var1', '23.24-24.78')], [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]]
#
# Update: []
# Update: [('SCentr_Range', '3255.0-10320.0')]
# Grown: [('SCentr_Range', '3255.0-10320.0'), ('SContr_mean4', '21.36-24.68')]
# Pruned to: [('SCentr_Range', '3255.0-10320.0'), ('SContr_mean4', '21.36-24.68')]
# {'Precision': 0.861878453038674, 'Recall': 1.3333333333333333}
# 0.861878453038674 1.3333333333333333
# test 9
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_mean0', '24.23-25.51')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_var6', '35.52-111.01')]
# Update: [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')]
# Update: [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45'), ('SContr_var5', '23.74-50.59')]
# Grown: [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45'), ('SContr_var5', '23.74-50.59'), ('SContr_mean5', '20.04-23.27')]
# Pruned to: [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_mean2', '27.09-29.9')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_mean3', '25.64-26.02')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean0', '22.52-23.38')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')]
# Pruned to: [('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.08')]
# Update: [('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0')]
# Grown: [('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0'), ('SContr_var0', '49.96-52.85')]
# Pruned to: [('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')], [('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Grown: [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')]
# Pruned to: [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')], [('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0')], [('SContr_var5', '9.26-15.4'), ('SContr_mean4', '26.73-27.07')]]
#
# Update: []
# Update: [('SContr_var3', '21.7-26.74')]
# Update: [('SContr_var3', '21.7-26.74'), ('SContr_mean5', '23.27-24.47')]
# Grown: [('SContr_var3', '21.7-26.74'), ('SContr_mean5', '23.27-24.47'), ('SContr_mean2', '21.15-23.56')]
# Pruned to: [('SContr_var3', '21.7-26.74'), ('SContr_mean5', '23.27-24.47'), ('SContr_mean2', '21.15-23.56')]
# {'Precision': 0.8936170212765957, 'Recall': 1.0677966101694916}
# 0.8936170212765957 1.0677966101694916
# test 10
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_mean0', '24.23-25.51')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_mean1', '23.23-26.7')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('Poly_mean', '0.08-0.08')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_var6', '35.52-111.01')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('SContr_var4', '25.97-55.62')]
# Pruned to: [('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('SContr_mean5', '25.95-34.8')]
# Grown: [('SContr_mean5', '25.95-34.8'), ('SContr_mean6', '36.88-45.02')]
# Pruned to: [('SContr_mean5', '25.95-34.8'), ('SContr_mean6', '36.88-45.02')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')], [('SContr_mean5', '25.95-34.8'), ('SContr_mean6', '36.88-45.02')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.08')]
# Update: [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4')]
# Grown: [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4'), ('SCentr_Range', '3255.0-10320.0')]
# Pruned to: [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')], [('SContr_mean5', '25.95-34.8'), ('SContr_mean6', '36.88-45.02')], [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4')]]
#
# Update: []
# Update: [('SContr_var0', '52.85-56.48')]
# Grown: [('SContr_var0', '52.85-56.48'), ('SContr_mean2', '26.39-27.09')]
# Pruned to: [('SContr_var0', '52.85-56.48'), ('SContr_mean2', '26.39-27.09')]
# {'Precision': 0.8978102189781022, 'Recall': 1.0695652173913044}
# 0.8978102189781022 1.0695652173913044
# test 11
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var5', '6.23-6.61')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_var4', '12.86-13.52')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('Tempo', '129.0-143.0')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '23.38-24.23')]
# Grown: [('SContr_mean0', '23.38-24.23'), ('SContr_var0', '56.48-61.08')]
# Pruned to: [('SContr_mean0', '23.38-24.23')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '23.38-24.23')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Pruned to: [('SContr_mean0', '22.52-23.38')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '23.38-24.23')], [('SContr_mean0', '22.52-23.38')]]
#
# Update: []
# Update: [('SContr_mean0', '21.54-22.52')]
# Grown: [('SContr_mean0', '21.54-22.52'), ('SContr_var0', '52.85-56.48')]
# Pruned to: [('SContr_mean0', '21.54-22.52')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '23.38-24.23')], [('SContr_mean0', '22.52-23.38')], [('SContr_mean0', '21.54-22.52')]]
#
# Update: []
# Update: [('SCentr_Range', '3255.0-10320.0')]
# Grown: [('SCentr_Range', '3255.0-10320.0'), ('SContr_mean4', '24.68-25.3')]
# Pruned to: [('SCentr_Range', '3255.0-10320.0'), ('SContr_mean4', '24.68-25.3')]
# {'Precision': 0.7733333333333333, 'Recall': 1.045045045045045}
# 0.7733333333333333 1.045045045045045
# test 12
# Update: []
# Grown: [('SContr_mean0', '25.51-28.21')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('Mode', 1)]
# Update: [('Mode', 1), ('Poly_mean', '0.08-0.08')]
# Grown: [('Mode', 1), ('Poly_mean', '0.08-0.08'), ('SContr_mean0', '24.23-25.51')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('SContr_mean0', '25.51-28.21')], [('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('Tempo', '129.0-143.0')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('SContr_mean0', '25.51-28.21')], [('Mode', 1)], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean0', '23.38-24.23')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('SContr_mean0', '25.51-28.21')], [('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('SContr_var6', '10.62-11.37')]
# Pruned to: [('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('SContr_mean0', '25.51-28.21')], [('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Grown: [('SContr_var5', '9.26-15.4'), ('SContr_mean6', '36.88-45.02')]
# Pruned to: [('SContr_var5', '9.26-15.4'), ('SContr_mean6', '36.88-45.02')]
# Updated ruleset: [[('SContr_mean0', '25.51-28.21')], [('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')], [('SContr_var5', '9.26-15.4'), ('SContr_mean6', '36.88-45.02')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.08')]
# Grown: [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '23.38-24.23')]
# Pruned to: [('Poly_mean', '0.08-0.08'), ('SContr_mean0', '23.38-24.23')]
# {'Precision': 0.8985507246376812, 'Recall': 1.0508474576271187}
# 0.8985507246376812 1.0508474576271187
# test 13
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var5', '6.23-6.61')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Grown: [('SContr_mean0', '25.51-28.21')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var4', '25.97-55.62')]
# Grown: [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')]
# Pruned to: [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.08')]
# Grown: [('Poly_mean', '0.08-0.08'), ('SContr_var6', '8.67-9.4')]
# Pruned to: [('Poly_mean', '0.08-0.08'), ('SContr_var6', '8.67-9.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')], [('Poly_mean', '0.08-0.08'), ('SContr_var6', '8.67-9.4')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('Interval_3', '4.3-4.41')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')], [('Poly_mean', '0.08-0.08'), ('SContr_var6', '8.67-9.4')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_var1', '23.24-24.78')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')], [('Poly_mean', '0.08-0.08'), ('SContr_var6', '8.67-9.4')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('SContr_var4', '25.97-55.62')]
# Pruned to: [('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')], [('Poly_mean', '0.08-0.08'), ('SContr_var6', '8.67-9.4')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Grown: [('SContr_var5', '9.26-15.4'), ('SContr_var3', '17.42-18.14')]
# Pruned to: [('SContr_var5', '9.26-15.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')], [('Poly_mean', '0.08-0.08'), ('SContr_var6', '8.67-9.4')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')], [('SContr_var5', '9.26-15.4')]]
#
# Update: []
# Update: [('SContr_var3', '26.74-55.45')]
# Grown: [('SContr_var3', '26.74-55.45'), ('Dissonance', '0.0-6.51')]
# Pruned to: [('SContr_var3', '26.74-55.45'), ('Dissonance', '0.0-6.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var4', '25.97-55.62'), ('SContr_mean0', '23.38-24.23')], [('Poly_mean', '0.08-0.08'), ('SContr_var6', '8.67-9.4')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var0', '61.08-89.82')], [('SContr_var5', '9.26-15.4')], [('SContr_var3', '26.74-55.45'), ('Dissonance', '0.0-6.51')]]
#
# Update: []
# Update: [('SContr_var2', '21.38-22.46')]
# Grown: [('SContr_var2', '21.38-22.46'), ('SCentr_Range', '1517.0-2203.0')]
# Pruned to: [('SContr_var2', '21.38-22.46'), ('SCentr_Range', '1517.0-2203.0')]
# {'Precision': 0.85, 'Recall': 1.2142857142857142}
# 0.85 1.2142857142857142
# test 14
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var5', '6.23-6.61')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_mean3', '25.64-26.02')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_mean1', '23.23-26.7')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var3', '26.74-55.45')]
# Update: [('SContr_var3', '26.74-55.45'), ('SContr_var5', '23.74-50.59')]
# Grown: [('SContr_var3', '26.74-55.45'), ('SContr_var5', '23.74-50.59'), ('Tempo', '99.0-112.0')]
# Pruned to: [('SContr_var3', '26.74-55.45')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '25.51-28.21')], [('SContr_var3', '26.74-55.45')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean2', '25.49-25.88')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '25.51-28.21')], [('SContr_var3', '26.74-55.45')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.08')]
# Update: [('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0')]
# Grown: [('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0'), ('SContr_var0', '49.96-52.85')]
# Pruned to: [('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0'), ('SContr_var0', '49.96-52.85')]
# {'Precision': 0.8823529411764706, 'Recall': 1.0169491525423728}
# 0.8823529411764706 1.0169491525423728
# test 15
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var5', '6.23-6.61')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('Tempo', '129.0-143.0')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_var6', '35.52-111.01')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SCentr_Range', '801.0-846.0')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('Tempo', '89.0-99.0')]
# Grown: [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')]
# Pruned to: [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')]]
#
# Update: []
# Update: [('SContr_mean0', '23.38-24.23')]
# Grown: [('SContr_mean0', '23.38-24.23'), ('SContr_mean1', '20.31-20.78')]
# Pruned to: [('SContr_mean0', '23.38-24.23')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')], [('SContr_mean0', '23.38-24.23')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('SContr_var6', '35.52-111.01')]
# Pruned to: [('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')], [('SContr_mean0', '23.38-24.23')], [('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.08')]
# Update: [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4')]
# Grown: [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4'), ('SContr_mean1', '20.31-20.78')]
# Pruned to: [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4'), ('SContr_mean1', '20.31-20.78')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')], [('SContr_mean0', '23.38-24.23')], [('SContr_var0', '61.08-89.82')], [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4'), ('SContr_mean1', '20.31-20.78')]]
#
# Update: []
# Update: [('SContr_var0', '49.96-52.85')]
# Grown: [('SContr_var0', '49.96-52.85'), ('SContr_var1', '24.78-26.66')]
# Pruned to: [('SContr_var0', '49.96-52.85'), ('SContr_var1', '24.78-26.66')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')], [('SContr_mean0', '23.38-24.23')], [('SContr_var0', '61.08-89.82')], [('Poly_mean', '0.08-0.08'), ('SContr_var5', '9.26-15.4'), ('SContr_mean1', '20.31-20.78')], [('SContr_var0', '49.96-52.85'), ('SContr_var1', '24.78-26.66')]]
#
# Update: []
# Update: [('SContr_var0', '49.96-52.85')]
# Grown: [('SContr_var0', '49.96-52.85'), ('SContr_var2', '19.0-21.38')]
# Pruned to: [('SContr_var0', '49.96-52.85'), ('SContr_var2', '19.0-21.38')]
# {'Precision': 0.88, 'Recall': 1.168141592920354}
# 0.88 1.168141592920354
# test 16
# Update: []
# Update: [('Mode', 1)]
# Update: [('Mode', 1), ('Poly_mean', '0.08-0.08')]
# Grown: [('Mode', 1), ('Poly_mean', '0.08-0.08'), ('SContr_mean6', '35.27-35.6')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_mean1', '23.23-26.7')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_mean3', '25.64-26.02')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean0', '23.38-24.23')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean0', '21.54-22.52')]
# Grown: [('SContr_mean0', '21.54-22.52'), ('Tempo', '89.0-99.0')]
# Pruned to: [('SContr_mean0', '21.54-22.52')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '21.54-22.52')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Update: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Grown: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0')]
# Pruned to: [('SContr_var5', '9.26-15.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '21.54-22.52')], [('SContr_var5', '9.26-15.4')]]
#
# Update: []
# Update: [('SContr_mean0', '23.38-24.23')]
# Grown: [('SContr_mean0', '23.38-24.23'), ('SContr_mean1', '20.31-20.78')]
# Pruned to: [('SContr_mean0', '23.38-24.23')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '21.54-22.52')], [('SContr_var5', '9.26-15.4')], [('SContr_mean0', '23.38-24.23')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('SContr_var0', '61.08-89.82')]
# ...
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Pruned to: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('SContr_var0', '56.48-61.08')], [('SContr_var5', '9.26-15.4')], [('SContr_mean1', '23.23-26.7'), ('SContr_var0', '61.08-89.82')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]]
#
# Update: []
# Update: [('SContr_var0', '49.96-52.85')]
# Grown: [('SContr_var0', '49.96-52.85'), ('SContr_mean0', '21.54-22.52')]
# Pruned to: [('SContr_var0', '49.96-52.85'), ('SContr_mean0', '21.54-22.52')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var6', '35.52-111.01'), ('SContr_var3', '26.74-55.45')], [('SContr_var0', '56.48-61.08')], [('SContr_var5', '9.26-15.4')], [('SContr_mean1', '23.23-26.7'), ('SContr_var0', '61.08-89.82')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('SContr_var0', '49.96-52.85'), ('SContr_mean0', '21.54-22.52')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.08')]
# Update: [('Poly_mean', '0.08-0.08'), ('SContr_var2', '19.0-21.38')]
# Grown: [('Poly_mean', '0.08-0.08'), ('SContr_var2', '19.0-21.38'), ('Dissonance', '8.35-8.6')]
# Pruned to: [('Poly_mean', '0.08-0.08'), ('SContr_var2', '19.0-21.38'), ('Dissonance', '8.35-8.6')]
# {'Precision': 0.8410596026490066, 'Recall': 1.2450980392156863}
# 0.8410596026490066 1.2450980392156863
# test 96
# Update: []
# Update: [('Mode', 1)]
# Update: [('Mode', 1), ('Poly_mean', '0.08-0.08')]
# Grown: [('Mode', 1), ('Poly_mean', '0.08-0.08'), ('SContr_var4', '11.93-12.86')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('Tempo', '99.0-112.0')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_mean1', '23.23-26.7')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('Poly_mean', '0.08-0.08')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Update: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Grown: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08'), ('SContr_mean4', '26.73-27.07')]
# Pruned to: [('SContr_var5', '9.26-15.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var5', '9.26-15.4')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('Poly_mean', '0.08-0.09')]
# Pruned to: [('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var5', '9.26-15.4')], [('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('SContr_var4', '25.97-55.62')]
# Update: [('SContr_var4', '25.97-55.62'), ('SContr_var6', '35.52-111.01')]
# Grown: [('SContr_var4', '25.97-55.62'), ('SContr_var6', '35.52-111.01'), ('SContr_mean1', '19.18-19.91')]
# Pruned to: [('SContr_var4', '25.97-55.62')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var5', '9.26-15.4')], [('SContr_var0', '61.08-89.82')], [('SContr_var4', '25.97-55.62')]]
#
# Update: []
# Update: [('SContr_mean5', '25.95-34.8')]
# Grown: [('SContr_mean5', '25.95-34.8'), ('Tonal_Clarity', '0.34-0.38')]
# Pruned to: [('SContr_mean5', '25.95-34.8'), ('Tonal_Clarity', '0.34-0.38')]
# Updated ruleset: [[('Mode', 1)], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var5', '9.26-15.4')], [('SContr_var0', '61.08-89.82')], [('SContr_var4', '25.97-55.62')], [('SContr_mean5', '25.95-34.8'), ('Tonal_Clarity', '0.34-0.38')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('SContr_var4', '13.52-14.34')]
# Pruned to: [('SContr_mean0', '22.52-23.38'), ('SContr_var4', '13.52-14.34')]
# {'Precision': 0.8305084745762712, 'Recall': 1.3363636363636364}
# 0.8305084745762712 1.3363636363636364
# test 97
# Update: []
# Update: [('Mode', 1)]
# Update: [('Mode', 1), ('Poly_mean', '0.08-0.08')]
# Grown: [('Mode', 1), ('Poly_mean', '0.08-0.08'), ('Tempo', '89.0-99.0')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Grown: [('SContr_mean0', '25.51-28.21')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_var4', '25.97-55.62')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_mean1', '20.78-21.18')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_mean1', '23.23-26.7')]
# Grown: [('SContr_mean1', '23.23-26.7'), ('Tempo', '99.0-112.0')]
# Pruned to: [('SContr_mean1', '23.23-26.7'), ('Tempo', '99.0-112.0')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean1', '23.23-26.7'), ('Tempo', '99.0-112.0')]]
#
# Update: []
# Update: [('SContr_var3', '26.74-55.45')]
# Update: [('SContr_var3', '26.74-55.45'), ('SContr_mean5', '20.04-23.27')]
# Grown: [('SContr_var3', '26.74-55.45'), ('SContr_mean5', '20.04-23.27'), ('SContr_var5', '23.74-50.59')]
# Pruned to: [('SContr_var3', '26.74-55.45')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean1', '23.23-26.7'), ('Tempo', '99.0-112.0')], [('SContr_var3', '26.74-55.45')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Update: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Grown: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08'), ('SContr_var4', '15.48-18.57')]
# Pruned to: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08'), ('SContr_var4', '15.48-18.57')]
# {'Precision': 0.8978102189781022, 'Recall': 1.0603448275862069}
# 0.8978102189781022 1.0603448275862069
# test 98
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('Tonal_Clarity', '0.22-0.24')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_var2', '24.45-25.91')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('Tempo', '129.0-143.0')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_mean0', '23.38-24.23')]
# Grown: [('SContr_mean0', '23.38-24.23'), ('Tonal_Clarity', '0.34-0.38')]
# Pruned to: [('SContr_mean0', '23.38-24.23')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '23.38-24.23')]]
#
# Update: []
# Update: [('SContr_var0', '61.08-89.82')]
# Grown: [('SContr_var0', '61.08-89.82'), ('SContr_mean1', '23.23-26.7')]
# Pruned to: [('SContr_var0', '61.08-89.82')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '23.38-24.23')], [('SContr_var0', '61.08-89.82')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean2', '25.49-25.88')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '23.38-24.23')], [('SContr_var0', '61.08-89.82')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('Dissonance', '8.13-8.35')]
# Pruned to: [('SContr_mean0', '22.52-23.38'), ('Dissonance', '8.13-8.35')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '23.38-24.23')], [('SContr_var0', '61.08-89.82')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '22.52-23.38'), ('Dissonance', '8.13-8.35')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Grown: [('SContr_var5', '9.26-15.4'), ('Tonal_Clarity', '0.32-0.34')]
# Pruned to: [('SContr_var5', '9.26-15.4')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '23.38-24.23')], [('SContr_var0', '61.08-89.82')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '22.52-23.38'), ('Dissonance', '8.13-8.35')], [('SContr_var5', '9.26-15.4')]]
#
# Update: []
# Update: [('SContr_mean0', '21.54-22.52')]
# Grown: [('SContr_mean0', '21.54-22.52'), ('Tempo', '89.0-99.0')]
# Pruned to: [('SContr_mean0', '21.54-22.52'), ('Tempo', '89.0-99.0')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_mean0', '23.38-24.23')], [('SContr_var0', '61.08-89.82')], [('SContr_var0', '56.48-61.08')], [('SContr_mean0', '22.52-23.38'), ('Dissonance', '8.13-8.35')], [('SContr_var5', '9.26-15.4')], [('SContr_mean0', '21.54-22.52'), ('Tempo', '89.0-99.0')]]
#
# Update: []
# Update: [('SContr_var0', '52.85-56.48')]
# Update: [('SContr_var0', '52.85-56.48'), ('Tonal_Clarity', '0.24-0.26')]
# Grown: [('SContr_var0', '52.85-56.48'), ('Tonal_Clarity', '0.24-0.26'), ('SContr_mean1', '20.78-21.18')]
# Pruned to: [('SContr_var0', '52.85-56.48'), ('Tonal_Clarity', '0.24-0.26'), ('SContr_mean1', '20.78-21.18')]
# {'Precision': 0.8, 'Recall': 1.28}
# 0.8 1.28
# test 99
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var4', '11.93-12.86')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('SContr_mean1', '23.23-26.7')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Update: [('SContr_mean0', '24.23-25.51')]
# Grown: [('SContr_mean0', '24.23-25.51'), ('SContr_mean2', '24.13-24.63')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean0', '23.38-24.23')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_var3', '26.74-55.45')]
# Grown: [('SContr_var3', '26.74-55.45'), ('SContr_mean5', '20.04-23.27')]
# Pruned to: [('SContr_var3', '26.74-55.45'), ('SContr_mean5', '20.04-23.27')]
# {'Precision': 0.8839285714285714, 'Recall': 0.9428571428571428}
# 0.8839285714285714 0.9428571428571428
# test 100
# Update: []
# Update: [('Mode', 1)]
# Grown: [('Mode', 1), ('SContr_var5', '6.23-6.61')]
# Pruned to: [('Mode', 1)]
# Updated ruleset: [[('Mode', 1)]]
#
# Update: []
# Update: [('SContr_mean0', '25.51-28.21')]
# Grown: [('SContr_mean0', '25.51-28.21'), ('Poly_mean', '0.08-0.08')]
# Pruned to: [('SContr_mean0', '25.51-28.21')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')]]
#
# Update: []
# Grown: [('SContr_mean0', '24.23-25.51')]
# Pruned to: [('SContr_mean0', '24.23-25.51')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')]]
#
# Update: []
# Update: [('SContr_var0', '56.48-61.08')]
# Grown: [('SContr_var0', '56.48-61.08'), ('SContr_mean0', '23.38-24.23')]
# Pruned to: [('SContr_var0', '56.48-61.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')]]
#
# Update: []
# Update: [('SContr_var5', '9.26-15.4')]
# Update: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Grown: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08'), ('SCentr_Range', '3255.0-10320.0')]
# Pruned to: [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')]]
#
# Update: []
# Update: [('SContr_mean0', '22.52-23.38')]
# Grown: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Pruned to: [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')]]
#
# Update: []
# Update: [('Tempo', '89.0-99.0')]
# Grown: [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')]
# Pruned to: [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')]]
#
# Update: []
# Update: [('SContr_var3', '26.74-55.45')]
# Grown: [('SContr_var3', '26.74-55.45'), ('SContr_var0', '61.08-89.82')]
# Pruned to: [('SContr_var3', '26.74-55.45')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')], [('SContr_var3', '26.74-55.45')]]
#
# Update: []
# Update: [('Poly_mean', '0.08-0.09')]
# Update: [('Poly_mean', '0.08-0.09'), ('SContr_mean1', '23.23-26.7')]
# Grown: [('Poly_mean', '0.08-0.09'), ('SContr_mean1', '23.23-26.7'), ('SContr_mean3', '27.67-30.76')]
# Pruned to: [('Poly_mean', '0.08-0.09'), ('SContr_mean1', '23.23-26.7'), ('SContr_mean3', '27.67-30.76')]
# Updated ruleset: [[('Mode', 1)], [('SContr_mean0', '25.51-28.21')], [('SContr_mean0', '24.23-25.51')], [('SContr_var0', '56.48-61.08')], [('SContr_var5', '9.26-15.4'), ('Poly_mean', '0.08-0.08')], [('SContr_mean0', '22.52-23.38'), ('Interval_6', '4.05-4.15')], [('Tempo', '89.0-99.0'), ('SContr_mean0', '21.54-22.52')], [('SContr_var3', '26.74-55.45')], [('Poly_mean', '0.08-0.09'), ('SContr_mean1', '23.23-26.7'), ('SContr_mean3', '27.67-30.76')]]
#
# Update: []
# Update: [('SContr_mean5', '25.95-34.8')]
# Update: [('SContr_mean5', '25.95-34.8'), ('SContr_var4', '14.34-15.48')]
# Grown: [('SContr_mean5', '25.95-34.8'), ('SContr_var4', '14.34-15.48'), ('Tempo', '143.0-161.0')]
# Pruned to: [('SContr_mean5', '25.95-34.8'), ('SContr_var4', '14.34-15.48'), ('Tempo', '143.0-161.0')]
# {'Precision': 0.8618421052631579, 'Recall': 1.1696428571428572}
# 0.8618421052631579 1.1696428571428572

# %%
results
# Out:
#                                                     Precision    Recall  \
# Ruleset
# [[(SContr_var0, 56.48-61.08)], [(SContr_mean0, ...   0.884621  0.826010
# [[(SContr_var0, 61.08-89.82)], [(SContr_var0, 5...   0.871035  1.023654
# [[(Tempo, 89.0-99.0)], [(SContr_var0, 61.08-89....   0.832464  1.231568
# [[(SContr_var5, 9.26-15.4), (SContr_mean4, 26.7...   0.905660  1.252174
# [[(SContr_var0, 61.08-89.82), (SContr_mean0, 22...   0.844262  0.927928
# [[(SContr_var3, 15.48-16.69), (SContr_var0, 56....   0.833333  0.791667
# [[(SContr_var3, 26.74-55.45), (SContr_var0, 61....   0.832117  1.027027
# [[(SContr_var3, 26.74-55.45)], [(SContr_var0, 5...   0.882353  1.016949
# [[(SContr_var5, 9.26-15.4), (Poly_mean, 0.08-0....   0.897810  1.069565
# [[(SContr_var5, 9.26-15.4), (Poly_mean, 0.08-0....   0.825000  0.970588
# [[(SContr_var5, 9.26-15.4), (SCentr_Range, 2203...   0.831933  0.980198
# [[(SContr_var5, 9.26-15.4)], [(SContr_var5, 6.2...   0.871166  1.224138
# [[(SContr_var5, 9.26-15.4), (SContr_var0, 52.85...   0.836735  1.033613
# [[(SContr_var5, 9.26-15.4)], [(SContr_var5, 6.2...   0.829787  1.000000
# [[(SContr_var5, 9.26-15.4), (SContr_var0, 52.85...   0.829787  0.966942
# [[(SContr_var5, 9.26-15.4), (SContr_var3, 21.7-...   0.895604  1.325203
# [[(SContr_var5, 9.26-15.4)], [(SContr_var0, 56....   0.774359  1.360360
# [[(SContr_var5, 9.26-15.4)], [(SContr_var0, 61....   0.767045  1.238532
# [[(SContr_var5, 9.26-15.4)], [(SContr_var3, 26....   0.844595  1.146789
# [[(SContr_var5, 9.26-15.4)], [(SContr_var4, 10....   0.895105  1.196262
# [[(SContr_var5, 9.26-15.4)], [(SContr_var5, 6.2...   0.861842  1.100840
# [[(SContr_var5, 9.26-15.4), (SContr_mean6, 36.8...   0.898551  1.050847
# [[(SContr_mean0, 25.51-28.21)], [(SContr_mean0,...   0.773333  1.045045
# [[(SContr_var6, 35.52-111.01), (SContr_var0, 56...   0.892473  0.728070
# [[(SContr_var6, 35.52-111.01), (SContr_var3, 26...   0.905512  1.084906
# [[(SContr_var6, 35.52-111.01)], [(SContr_var5, ...   0.864000  1.000000
# [[(SContr_var6, 35.52-111.01), (SContr_var3, 26...   0.884956  0.943396
# [[(SContr_var6, 35.52-111.01), (SContr_var3, 26...   0.814103  1.154545
# [[(SContr_var6, 35.52-111.01), (SContr_var3, 26...   0.841060  1.245098
# [[(SContr_var6, 35.52-111.01), (SContr_var4, 25...   0.867925  0.920000
# ...                                                       ...       ...
# [[(Tempo, 89.0-99.0), (SContr_mean1, 20.78-21.1...   0.886228  1.298246
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.842593  0.827273
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.810127  1.174312
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.880000  1.316239
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.869565  1.261261
# [[(Tempo, 89.0-99.0), (SContr_mean0, 21.54-22.5...   0.800000  1.280000
# [[(SContr_mean0, 25.51-28.21)], [(SContr_mean0,...   0.939759  0.715596
# [[(Tempo, 89.0-99.0), (SContr_mean0, 21.54-22.5...   0.867925  1.243243
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.818966  0.959596
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.801325  1.174757
# [[(Tempo, 99.0-112.0), (SContr_mean1, 23.23-26....   0.897810  1.060345
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.829268  1.247706
# [[(Tempo, 89.0-99.0)], [(SContr_var0, 61.08-89....   0.857143  1.239669
# [[(Tempo, 89.0-99.0)], [(SContr_var0, 61.08-89....   0.865497  1.370370
# [[(Tempo, 89.0-99.0)], [(SContr_var3, 26.74-55....   0.887218  1.072727
# [[(Tempo, 89.0-99.0)], [(SContr_var5, 9.26-15.4...   0.861878  1.333333
# [[(Tempo, 89.0-99.0)], [(SContr_var5, 9.26-15.4...   0.906040  1.163793
# [[(Tempo, 89.0-99.0)], [(SContr_var5, 9.26-15.4...   0.763736  1.275229
# [[(Tempo, 99.0-112.0), (SContr_mean0, 21.54-22....   0.833333  1.127451
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean0, 21...   0.852564  1.254717
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.921739  1.000000
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean0, 21...   0.877193  1.219512
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean0, 21...   0.877419  1.123967
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...   0.906040  1.184211
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...   0.830508  1.336364
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...   0.865031  1.355769
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...   0.882075  1.640351
# [[(Tempo, 89.0-99.0), (Poly_mean, 0.08-0.08)], ...   0.817647  1.287037
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...   0.861111  0.861111
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...   0.845304  1.342105
#
#                                                     Freq_Selected
# Ruleset
# [[(SContr_var0, 56.48-61.08)], [(SContr_mean0, ...           0.06
# [[(SContr_var0, 61.08-89.82)], [(SContr_var0, 5...           0.06
# [[(Tempo, 89.0-99.0)], [(SContr_var0, 61.08-89....           0.02
# [[(SContr_var5, 9.26-15.4), (SContr_mean4, 26.7...           0.01
# [[(SContr_var0, 61.08-89.82), (SContr_mean0, 22...           0.01
# [[(SContr_var3, 15.48-16.69), (SContr_var0, 56....           0.01
# [[(SContr_var3, 26.74-55.45), (SContr_var0, 61....           0.01
# [[(SContr_var3, 26.74-55.45)], [(SContr_var0, 5...           0.01
# [[(SContr_var5, 9.26-15.4), (Poly_mean, 0.08-0....           0.01
# [[(SContr_var5, 9.26-15.4), (Poly_mean, 0.08-0....           0.01
# [[(SContr_var5, 9.26-15.4), (SCentr_Range, 2203...           0.01
# [[(SContr_var5, 9.26-15.4)], [(SContr_var5, 6.2...           0.01
# [[(SContr_var5, 9.26-15.4), (SContr_var0, 52.85...           0.01
# [[(SContr_var5, 9.26-15.4)], [(SContr_var5, 6.2...           0.01
# [[(SContr_var5, 9.26-15.4), (SContr_var0, 52.85...           0.01
# [[(SContr_var5, 9.26-15.4), (SContr_var3, 21.7-...           0.01
# [[(SContr_var5, 9.26-15.4)], [(SContr_var0, 56....           0.01
# [[(SContr_var5, 9.26-15.4)], [(SContr_var0, 61....           0.01
# [[(SContr_var5, 9.26-15.4)], [(SContr_var3, 26....           0.01
# [[(SContr_var5, 9.26-15.4)], [(SContr_var4, 10....           0.01
# [[(SContr_var5, 9.26-15.4)], [(SContr_var5, 6.2...           0.01
# [[(SContr_var5, 9.26-15.4), (SContr_mean6, 36.8...           0.01
# [[(SContr_mean0, 25.51-28.21)], [(SContr_mean0,...           0.01
# [[(SContr_var6, 35.52-111.01), (SContr_var0, 56...           0.01
# [[(SContr_var6, 35.52-111.01), (SContr_var3, 26...           0.01
# [[(SContr_var6, 35.52-111.01)], [(SContr_var5, ...           0.01
# [[(SContr_var6, 35.52-111.01), (SContr_var3, 26...           0.01
# [[(SContr_var6, 35.52-111.01), (SContr_var3, 26...           0.01
# [[(SContr_var6, 35.52-111.01), (SContr_var3, 26...           0.01
# [[(SContr_var6, 35.52-111.01), (SContr_var4, 25...           0.01
# ...                                                           ...
# [[(Tempo, 89.0-99.0), (SContr_mean1, 20.78-21.1...           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tempo, 89.0-99.0), (SContr_mean0, 21.54-22.5...           0.01
# [[(SContr_mean0, 25.51-28.21)], [(SContr_mean0,...           0.01
# [[(Tempo, 89.0-99.0), (SContr_mean0, 21.54-22.5...           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tempo, 99.0-112.0), (SContr_mean1, 23.23-26....           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tempo, 89.0-99.0)], [(SContr_var0, 61.08-89....           0.01
# [[(Tempo, 89.0-99.0)], [(SContr_var0, 61.08-89....           0.01
# [[(Tempo, 89.0-99.0)], [(SContr_var3, 26.74-55....           0.01
# [[(Tempo, 89.0-99.0)], [(SContr_var5, 9.26-15.4...           0.01
# [[(Tempo, 89.0-99.0)], [(SContr_var5, 9.26-15.4...           0.01
# [[(Tempo, 89.0-99.0)], [(SContr_var5, 9.26-15.4...           0.01
# [[(Tempo, 99.0-112.0), (SContr_mean0, 21.54-22....           0.01
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean0, 21...           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean0, 21...           0.01
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean0, 21...           0.01
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...           0.01
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...           0.01
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...           0.01
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...           0.01
# [[(Tempo, 89.0-99.0), (Poly_mean, 0.08-0.08)], ...           0.01
# [[(Tempo, 89.0-99.0), (SContr_var0, 49.96-52.85...           0.01
# [[(Tonal_Clarity, 0.34-0.38), (SContr_mean5, 25...           0.01
#
# [89 rows x 3 columns]

# %%
results['Weighted_Precision'] = results['Precision']*results['Freq_Selected']

# %%
results['Weighted_Precision'].sum()
# Out:
# 0.858897814091796
